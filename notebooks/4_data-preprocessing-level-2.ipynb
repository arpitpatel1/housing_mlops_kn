# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
in_path = Path('../data/raw')
out_path = Path('../data/interim')

# %%
flats_1 = pd.read_csv(in_path / 'flats_1.csv')
flats_2 = pd.read_csv(in_path / 'flats_2.csv')
df = pd.read_csv(in_path / 'properties.csv')

# %%
df.shape
# Out:
# (7794, 21)

# %%
df.sample(5)
# Out:
#                                    property_name property_type  \
# 4065  4 Bedroom House for sale in Maninagar East         house
# 6075                        2 BHK Flat in Naroda          flat
# 5195                       3 BHK Flat in Thaltej          flat
# 4908                         2 BHK Flat in Narol          flat
# 5490                   3 BHK Flat in South Bopal          flat
#
#                           society  price  price_per_sqft    area  \
# 4065                  independent   1.50          8333.0  1800.0
# 6075                   tirthraj 4   0.35          4666.0   750.0
# 5195  ganesh housing maple county   1.45          6444.0  2250.0
# 4908             sangani platinum   0.25          2620.0   954.0
# 5490                    gala aria   1.25          5910.0  2115.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 4065                        Plot area 200(167.23 sq.m.)        4         2
# ...

# %%
df.shape
# Out:
# (7794, 21)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# df.info()

# %%
# df.isnull().sum()

# %%
# df.head()

# %%
flats_1.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('ahmedabad','').str.strip())
flats_1['sector'] = flats_1['sector'].str.lower()
flats_1['sector'].value_counts()
# Out:
# sector
# gota                                                171
# south bopal                                         162
# chandkheda                                           98
# science city                                         90
# satellite                                            85
# vastral                                              79
# jagatpur                                             72
# shela                                                69
# bodakdev                                             55
# motera                                               55
# man                                                  54
# paldi                                                46
# vatva                                                46
# naroda                                               46
# nikol                                                45
# vastrapur                                            43
# bopal                                                42
# ...

# %%
flats_2.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('ahmedabad','').str.strip())
flats_2['sector'] = flats_2['sector'].str.lower()
flats_2['sector'].value_counts()
# Out:
# sector
# south bopal                                                 351
# gota                                                        319
# chandkheda                                                  199
# science city                                                173
# satellite                                                   158
# vastral                                                     147
# shela                                                       141
# jagatpur                                                    128
# bodakdev                                                    117
# man                                                         113
# motera                                                      113
# naroda                                                       99
# nikol                                                        88
# thaltej                                                      88
# ghuma                                                        84
# ...

# %%
df.insert(loc=3,column='sector',value=df['property_name'].str.split('in').str.get(1).str.replace('ahmedabad','').str.strip())

# %%
# df.head()

# %%
df['sector'] = df['sector'].str.lower()

# %%
# df.head()

# %%
df['sector'].value_counts()
# Out:
# sector
# south bopal                                                 586
# gota                                                        541
# chandkheda                                                  334
# science city                                                305
# shela                                                       252
# vastral                                                     252
# satellite                                                   243
# jagatpur                                                    218
# bodakdev                                                    214
# motera                                                      203
# man                                                         202
# naroda                                                      175
# nikol                                                       156
# thaltej                                                     148
# vatva                                                       136
# ...

# %%
df[df['sector']=='cha']
# Out:
#                              property_name property_type  \
# 613                 1 BHK Flat in Chainpur          flat
# 4468                2 BHK Flat in Chainpur          flat
# 5652  2 Bedroom House for sale in Chainpur         house
# 6691                2 BHK Flat in Chainpur          flat
#
#                     society sector  price  price_per_sqft    area  \
# 613      shiv ganesh vatika    cha   0.33         40625.0    81.0
# 4468  aum nirman life style    cha   0.35          3411.0  1026.0
# 5652  abhay ratna row house    cha   0.53          6543.0   810.0
# 6691  ganesh vatika chenpur    cha   0.53          5077.0  1044.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 613                        Carpet area: 80 (7.43 sq.m.)        1         1
# 4468  Super Built up area 1026(95.32 sq.m.)Built Up ...        2         2
# 5652                          Plot area 90(75.25 sq.m.)        2         2
# ...

# %%
df = df[~df['sector'].isin(['kashindra', 'manipur', 'kudasan', 'sardar patel r','adalaj','raysan','bareja','jetalpur','sudhad','vavol',
                            'kuha','palodia','moraiya','khoraj','khodiyar','bagodara','godhavi','randheja','randesan','dholka','kalol','saroda',
                           'mandal','kas','changodar','gandh','kolat','nasmed','sector 13 gandh','barejadi','sector 21 gandh',
                           'sector 26 gandh','bilasiya','sector 8 gandh','chaloda','near sanand railway station','nandej',
                           'sector 29 gandh','lapkaman','gift city','kalikund','adroda','bakarol','rancharda','sector 3 gandh',
                            'sector 2 gandh','sector 6 gandh','sector 2b gandh','nandoli','sector 5 gandh','sector 4 gandh','khaneti road, sanand',
                            'shantigram','sector 30 gandh','ja','wapa','shr','sterl','cha','sanand'])]

# %%
df['sector'] = df['sector'].str.replace('shastr','shastrinagar')
# df['sector'] = df['sector'].str.replace('cha','ranip')
df['sector'] = df['sector'].str.replace('chandlodia talav','chandlodia')
df['sector'] = df['sector'].str.replace('jivraj park,vejalpur','jivraj park')
df['sector'] = df['sector'].str.replace('vaishnodevi circle, s g highway','vaishnodevi circle')

# %%
df['sector'] = df['sector'].str.replace('narolgam','narol')
# df['sector'] = df['sector'].str.replace('v','vinzol')
df['sector'] = df['sector'].str.replace('nikol naroda road','nikol')
df['sector'] = df['sector'].str.replace('saijpur bogha','naroda')
df['sector'] = df['sector'].str.replace('bhatta','paldi')
df['sector'] = df['sector'].str.replace('parishram residency 4 nr madhavinzol falt bopal','bopal')
df['sector'] = df['sector'].str.replace('opp kubereswar mahadevinzol, naroda,naroda road','naroda')
df['sector'] = df['sector'].str.replace('ambicanagar, odhav','odhav')
df['sector'] = df['sector'].str.replace('viratnagar road, nikol','nikol')
df['sector'] = df['sector'].str.replace('on riverfrount , usmanpura','usmanpura')
df['sector'] = df['sector'].str.replace('chandranagar char rasta ,paldi','paldi')
df['sector'] = df['sector'].str.replace('vastral road','vastral')
df['sector'] = df['sector'].str.replace('narayan nagar, paldi','paldi')
df['sector'] = df['sector'].str.replace('parshwnath,kirishnanagar','krishnanagar')
df['sector'] = df['sector'].str.replace('shela bopal','shela')
df['sector'] = df['sector'].str.replace('uttamnagar, nikol','nikol')
df['sector'] = df['sector'].str.replace('ghodasar vatva','ghodasar')
df['sector'] = df['sector'].str.replace('cadila bridge, ghodasar','ghodasar')
df['sector'] = df['sector'].str.replace('k. k. nagar ghatlodiya','ghatlodiya')
df['sector'] = df['sector'].str.replace('usmanpura, ashram road','usmanpura')
df['sector'] = df['sector'].str.replace('scince city','science city')
df['sector'] = df['sector'].str.replace('ghodashar','ghodasar')
df['sector'] = df['sector'].str.replace('shilaj - rancharda road','shilaj')
df['sector'] = df['sector'].str.replace('sola road, naranpura','naranpura')
df['sector'] = df['sector'].str.replace('vyaswadi, nava wadaj','nava wadaj')
df['sector'] = df['sector'].str.replace('gokul dham applewood shela','shela')
df['sector'] = df['sector'].str.replace('chandkheda ahmedbad north','chandkheda')
df['sector'] = df['sector'].str.replace('nikol bhakti circle','nikol')
df['sector'] = df['sector'].str.replace('chandlodia, gota','chandlodia')
df['sector'] = df['sector'].str.replace('thaltej baghbaan party plot','thaltej')
df['sector'] = df['sector'].str.replace('khokra,near baal bhavan,beside dharmajivan flate','khokhra')
df['sector'] = df['sector'].str.replace('vatva gam','vatva')
df['sector'] = df['sector'].str.replace('naroda d mart','naroda')
df['sector'] = df['sector'].str.replace('bapunagar l b shashtri road','bapunagar')
df['sector'] = df['sector'].str.replace('opp kargil petrolpump, s.g highway, ghatlodia','ghatlodia')
df['sector'] = df['sector'].str.replace('krishnanagar naroda','krishnanagar')

# %%
a = df['sector'].value_counts()[df['sector'].value_counts() >= 3]
df = df[df['sector'].isin(a.index)]

# %%
df.shape
# Out:
# (7176, 22)

# %%
df['sector'].value_counts()
# Out:
# sector
# south bopal            586
# gota                   541
# chandkheda             335
# science city           306
# shela                  254
# vastral                253
# satellite              243
# jagatpur               218
# bodakdev               214
# motera                 203
# man                    202
# naroda                 183
# nikol                  173
# thaltej                149
# vatva                  137
# bopal                  135
# narol                  134
# paldi                  133
# new ranip              131
# ghuma                  130
# vastrapur              115
# nava naroda            102
# memnagar                92
# shilaj                  74
# sola                    72
# ghodasar                68
# isanpur                 67
# jodhpur                 59
# ghatlodia               59
# vaishnodevi circle      59
# charodi                 58
# gurukul                 58
# bapunagar               57
# sanathal                49
# ...

# %%
take_1 = ['shela','thaltej','shilaj','isanpur','vaishnodevi circle','ghatlodia','bhadaj','shahibaug',
        'sg highway','naranpura','vasna','chandlodia','ctm','nana chiloda','sarkhej','krishna nagar',
        'new man','navrangpura','usmanpura']
take_2 = ['gota', 'south bopal', 'chandkheda', 'satellite', 'jagatpur', 'vastral',
       'bodakdev', 'science city', 'motera', 'man', 'naroda', 'nikol',
       'new ranip', 'vatva', 'paldi', 'vastrapur', 'nava naroda', 'narol',
       'ghuma', 'memnagar', 'charodi', 'sola', 'jodhpur', 'gurukul',
       'koteshwar', 'odhav', 'bapunagar', 'prahlad nagar', 'khokhara']
take = take_1 + take_2

# here comes the manual assesment , take2 is the areas which were present in flats_2 , 
# and take1 is an important areas in flats_1 and are not present in flats_2.
# we will select combine areas of take1 and take2 from ahmedabad_properties data.

# %%
len(take)
# Out:
# 48

# %%
sector_list = df['sector'].value_counts().index.tolist()

# %%
values_not_in_list1 = [value for value in take_2 if value not in sector_list]

# %%
values_not_in_list1
# Out:
# []

# %%
df = df[df['sector'].isin(take)]

# %%
df.head()
# Out:
#                               property_name property_type  \
# 1                        3 BHK Flat in Gota          flat
# 4   5 Bedroom House for sale in South Bopal         house
# 6                        2 BHK Flat in Gota          flat
# 10                   3 BHK Flat in Memnagar          flat
# 11  3 Bedroom House for sale in South Bopal         house
#
#                    society       sector  price  price_per_sqft    area  \
# 1             olive greens         gota   0.90          9313.0   966.0
# 4    aamramanjari bunglows  south bopal   6.40         16049.0  3988.0
# 6   avirat silver gardenia         gota   0.62          7607.0   815.0
# 10         preet residency     memnagar   0.85          5666.0  1500.0
# 11             independent  south bopal   2.30          9536.0  2412.0
#
#                                          areaWithType  bedRoom  bathroom  \
# 1   Super Built up area 1918(178.19 sq.m.)Built Up...        3         3
# ...

# %%
df['sector'].unique()
# Out:
# array(['gota', 'south bopal', 'memnagar', 'narol', 'motera', 'vastrapur',
#        'shela', 'nikol', 'naroda', 'man', 'chandkheda', 'bodakdev',
#        'jagatpur', 'koteshwar', 'vaishnodevi circle', 'vatva',
#        'sg highway', 'navrangpura', 'ghatlodia', 'new ranip', 'new man',
#        'paldi', 'bapunagar', 'satellite', 'gurukul', 'sola', 'vastral',
#        'ghuma', 'isanpur', 'science city', 'thaltej', 'nava naroda',
#        'bhadaj', 'shilaj', 'vasna', 'charodi', 'jodhpur', 'sarkhej',
#        'odhav', 'shahibaug', 'chandlodia', 'ctm', 'prahlad nagar',
#        'khokhara', 'naranpura', 'nana chiloda', 'krishna nagar',
#        'usmanpura'], dtype=object)

# %%
df['sector'].replace({'man': 'maninagar','new man':'new maninagar'}, inplace=True)

# %%
df.shape
# Out:
# (5933, 22)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head()
# Out:
#                               property_name property_type  \
# 1                        3 BHK Flat in Gota          flat
# 4   5 Bedroom House for sale in South Bopal         house
# 6                        2 BHK Flat in Gota          flat
# 10                   3 BHK Flat in Memnagar          flat
# 11  3 Bedroom House for sale in South Bopal         house
#
#                    society       sector  price  price_per_sqft    area  \
# 1             olive greens         gota   0.90          9313.0   966.0
# 4    aamramanjari bunglows  south bopal   6.40         16049.0  3988.0
# 6   avirat silver gardenia         gota   0.62          7607.0   815.0
# 10         preet residency     memnagar   0.85          5666.0  1500.0
# 11             independent  south bopal   2.30          9536.0  2412.0
#
#                                          areaWithType  bedRoom  bathroom  \
# 1   Super Built up area 1918(178.19 sq.m.)Built Up...        3         3
# ...

# %%
# features to drop -> property_name, address, description, rating
df.drop(columns=['property_name', 'address', 'description', 'rating'],inplace=True)

# %%
df.sample(5)
# Out:
#      property_type                        society       sector  price  \
# 7413          flat         vishwanath maher homes        shela   0.62
# 5811          flat                     manthan 25        vatva   0.30
# 3804         house                    independent        nikol   1.00
# 2720          flat  dharmadev swaminarayan park 6        narol   0.15
# 3741          flat           kavisha celebrations  south bopal   0.85
#
#       price_per_sqft    area  \
# 7413          5581.0  1111.0
# 5811         24710.0   121.0
# 3804          5556.0  1800.0
# 2720          1961.0   765.0
# 3741          5862.0  1450.0
#
#                                            areaWithType  bedRoom  bathroom  \
# 7413              Super Built up area 1075(99.87 sq.m.)        2         2
# 5811                     Carpet area: 121 (11.24 sq.m.)        2         2
# 3804                 Built Up area: 1800 (167.23 sq.m.)        5         3
# ...

# %%
# feature engineering required -> areaWithType, additionalRoom, facing, agePossession, furnishDetails, features

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, additionalRoom, floorNum, facing, agePossession, nearbyLocations, furnishDetails, features, property_id]
# Index: []

# %%
df.drop_duplicates(subset='property_id',inplace=True)

# %%
df.to_csv(out_path / 'properties_cleaned_v1.csv',index=False)
