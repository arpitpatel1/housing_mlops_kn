# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
in_path = Path('../data/raw')
out_path = Path('../data/interim')

# %%
flats = pd.read_csv(in_path / 'flats_cleaned.csv')
houses = pd.read_csv(in_path / 'house_cleaned.csv')

# %%
houses.head(5)
# Out:
#                           property_name property_type  \
# 0     3 Bedroom House for sale in Ghuma         house
# 1  4 Bedroom House for sale in Sanathal         house
# 2  3 Bedroom House for sale in Randheja         house
# 3     3 Bedroom House for sale in Bopal         house
# 4    5 Bedroom House for sale in Enasan         house
#
#                        society  price  price_per_sqft    area  \
# 0          individual bunglowe   1.25          8267.0  1512.0
# 1             goyal green park   3.00          8333.0  3600.0
# 2  maruti independentdan green   0.80          4400.0  1818.0
# 3      b/37, jahanvi bungalows   3.20         37427.0   855.0
# 4             akash grand city   4.35          8606.0  5055.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                        Plot area 168(140.47 sq.m.)        3         3
# 1  Plot area 400(334.45 sq.m.)Built Up area: 350 ...        4         4
# 2                         Plot area 202(168.9 sq.m.)        3         4
# 3  Plot area 370(309.37 sq.m.)Built Up area: 176 ...        3         3
# 4                        Plot area 581(485.79 sq.m.)        5         6
#
#   balcony  ...                                 address floorNum      facing  \
# 0       1  ...        Ghuma, Ahmedabad West, Ahmedabad      2.0  South-East
# 1       2  ...     Sanathal, Ahmedabad West, Ahmedabad      2.0  South-West
# 2       1  ...        Randheja, Gandhinagar, Ahmedabad      2.0  North-East
# 3       2  ...  B/37, Bopal, Ahmedabad West, Ahmedabad      3.0       North
# 4       1  ...      Enasan, Ahmedabad North, Ahmedabad      2.0         NaN
#
#         agePossession                                    nearbyLocations  \
# 0    5 to 10 Year Old  ['Atm hdfc bank', 'State bank of india sbi ATM...
# 1        10+ Year Old  ['Sahyog General Hospital and Nursing Home', '...
# 2  Under Construction                                                NaN
# 3        10+ Year Old  ['Icici ATM', 'Hdfc ATM', 'Atm hdfc bank', 'Ax...
# 4     1 to 5 Year Old                                                NaN
#
#                                          description  \
# 0  Are you planning to buy your dream home? You c...
# 1  A residential bungalows is available for sale ...
# 2  Check out this 3 bhk house for sale in randhej...
# 3  An impeccable opportunity is here for those wh...
# 4  I have a house/villa available for sale in ena...
#
#                                       furnishDetails  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  ['4 Wardrobe', '13 Fan', '1 Exhaust Fan', '2 G...
# 4                                                 []
#
#                                             features  \
# 0  ['Feng Shui / Vaastu Compliant', 'Visitor Park...
# 1  ['Feng Shui / Vaastu Compliant', 'Private Gard...
# 2                                                NaN
# 3  ['Private Garden / Terrace', 'Water purifier',...
# 4                  ['Club house / Community Center']
#
#                                               rating property_id
# 0  ['Lifestyle3.7 out of 5', 'Connectivity4.1 out...   Y66780728
# 1                                                NaN   V69832032
# 2                                                NaN   W68654880
# 3  ['Lifestyle4.2 out of 5', 'Connectivity4.3 out...   U69163438
# 4                                                NaN   M68168346
#
# [5 rows x 21 columns]

# %%
df = pd.concat([flats,houses],ignore_index=True)

# %%
df.shape
# Out:
# (7794, 21)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df = df.sample(df.shape[0],ignore_index=True)

# %%
df.head()
# Out:
#                                property_name property_type  \
# 0       3 Bedroom House for sale in Hathijan         house
# 1                         3 BHK Flat in Gota          flat
# 2          4 Bedroom House for sale in Ranip         house
# 3  3 Bedroom House for sale in Jashoda Nagar         house
# 4    5 Bedroom House for sale in South Bopal         house
#
#                  society  price  price_per_sqft    area  \
# 0    shivam pushpak city   1.00          9873.0  1013.0
# 1           olive greens   0.90          9313.0   966.0
# 2         sagar tenament   1.05         11667.0   900.0
# 3     pushparaj bunglows   1.25         65104.0   192.0
# 4  aamramanjari bunglows   6.40         16049.0  3988.0
#
#                                         areaWithType  bedRoom  bathroom  \
# 0                                     Plot area 94.1        3         4
# 1  Super Built up area 1918(178.19 sq.m.)Built Up...        3         3
# 2  Plot area 100(83.61 sq.m.)Built Up area: 180 s...        4         3
# 3                         Plot area 192(17.84 sq.m.)        3         3
# 4  Plot area 450(376.26 sq.m.)Built Up area: 600 ...        5         5
#
#   balcony  ...                                    address floorNum  \
# 0       2  ...  A-44, Hathijan, Ahmedabad East, Ahmedabad      2.0
# 1       1  ...      302, Gota, Ahmedabad North, Ahmedabad      3.0
# 2       2  ...     100, Ranip, Ahmedabad North, Ahmedabad      2.0
# 3       1  ...   Jashoda Nagar, Ahmedabad East, Ahmedabad      2.0
# 4       2  ...     South Bopal, Ahmedabad West, Ahmedabad      1.0
#
#        facing     agePossession  \
# 0         NaN  5 to 10 Year Old
# 1        East   1 to 5 Year Old
# 2  North-East   1 to 5 Year Old
# 3        East      10+ Year Old
# 4        East   1 to 5 Year Old
#
#                                      nearbyLocations  \
# 0                                                NaN
# 1  ['Fraucow Shopping Mall', 'S G Business Hub', ...
# 2                                                NaN
# 3  ['Mahadev Temple', 'Temple', 'Saibaba Temple',...
# 4  ['Icici ATM', 'State bank of india sbi ATM', '...
#
#                                          description  \
# 0  Front side galary and back side galary and rea...
# 1  Heck out olive greens in gota, one of the upco...
# 2  4 bhk newley constructed bunglow available for...
# 3      It is bunglow,with huge extra space in front.
# 4  This is a aamramanjri bunglows meticulously de...
#
#                                       furnishDetails  \
# 0  ['4 Bed', '3 Wardrobe', '1 Fridge', '1 Sofa', ...
# 1                                                NaN
# 2  ['1 Water Purifier', '4 Fan', '1 Fridge', '1 E...
# 3                                                NaN
# 4  ['1 Water Purifier', '5 Fan', '1 Dining Table'...
#
#                                             features  \
# 0  ['Private Garden / Terrace', 'High Ceiling Hei...
# 1  ['Security / Fire Alarm', 'Feng Shui / Vaastu ...
# 2  ['Feng Shui / Vaastu Compliant', 'Water Storag...
# 3  ['Feng Shui / Vaastu Compliant', 'Water Storag...
# 4  ['Security / Fire Alarm', 'Water Storage', 'Vi...
#
#                                               rating property_id
# 0                                                NaN   G68072174
# 1  ['Lifestyle4.2 out of 5', 'Connectivity4.1 out...   L63689388
# 2  ['Lifestyle3.8 out of 5', 'Connectivity4.2 out...   F70508100
# 3  ['Lifestyle3.6 out of 5', 'Connectivity3.7 out...   K64734078
# 4  ['Lifestyle4.2 out of 5', 'Connectivity4.3 out...   C69028840
#
# [5 rows x 21 columns]

# %%
df.to_csv(out_path / 'properties.csv',index=False)
